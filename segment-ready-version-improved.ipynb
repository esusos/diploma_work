# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import random

# %%
path_to_images = '/kaggle/input/teeth-segment/Teeth pictires/images_cut'
path_to_labels = '/kaggle/input/teeth-segment/Teeth pictires/labels_cut'

# %%
list_of_image_files = os.listdir(path_to_images)
list_of_label_files = os.listdir(path_to_labels)

# %%
image_file_count = len(list_of_image_files)
label_file_count = len(list_of_label_files)

categories = ['Images', 'Labels']
counts = [image_file_count, label_file_count]

plt.figure(figsize=(8, 5))
plt.bar(categories, counts, color=['blue', 'green'])

plt.xlabel('File Types')
plt.ylabel('Number of Files')
plt.title('Comparison of Image and Label Files')

for i, count in enumerate(counts):
    plt.text(i, count + 1, str(count), ha='center')

plt.tight_layout()
plt.show()

# %%
sampled_images = np.random.choice(list_of_image_files, size=15, replace=False)

# %%
import cv2 

dimension = 512
target_size = (dimension, dimension)

def load_and_process_image(file_path):
    image = cv2.imread(file_path)
    image = cv2.resize(image, target_size)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
count=200
grid_rows = 5
grid_cols = 3

figure, axes = plt.subplots(grid_rows, grid_cols, figsize=(10, 10))
for index, axis in enumerate(axes.flatten()):
    if index < len(sampled_images):  
        image_path = f"{path_to_images}/{sampled_images[index]}"
        processed_image = load_and_process_image(image_path)
        axis.set_title(sampled_images[index])
        axis.imshow(processed_image)
        axis.axis('off')

# %%
# Original Verification Masks

fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(20, 12)) 
for i, ax in enumerate(axes.flatten()):
    if i < len(sampled_images):
        file_name = sampled_images[i]
        file_path = os.path.join(path_to_labels, file_name)
        if os.path.exists(file_path):
            img = cv2.imread(file_path, cv2.COLOR_BGR2GRAY) 
            ax.set_title(file_name)
            ax.imshow(img, cmap='gray')  
            ax.axis('off')
        else:
            ax.set_title('Missing')
            ax.axis('off')
    else:
        ax.axis('off')
plt.tight_layout()
plt.show()

# %%
PREPARED_MASKS = np.zeros((1, dimension, dimension, 1), dtype=bool)
PREPARED_IMAGES = np.zeros((1, dimension, dimension, 3), dtype=np.uint8)

# %%
for idx, filename in enumerate(os.listdir(path_to_images)[:count]):
    try:
        processed_image = load_and_process_image(os.path.join(path_to_images, filename))
        expanded_image = np.expand_dims(processed_image, axis=0)
        PREPARED_IMAGES = np.vstack((PREPARED_IMAGES, expanded_image))

        processed_mask = load_and_process_image(os.path.join(path_to_labels, filename))
        gray_mask = cv2.cvtColor(processed_mask, cv2.COLOR_BGR2GRAY)
        reshaped_mask = gray_mask.reshape(dimension, dimension, 1)
        expanded_mask = np.expand_dims(reshaped_mask, axis=0)
        PREPARED_MASKS = np.vstack((PREPARED_MASKS, expanded_mask))

    except Exception as e:
        print(f"Error processing {filename}: {e}")
        continue

# %%
final_images = np.array(PREPARED_IMAGES)[1:count+1]
final_masks = np.array(PREPARED_MASKS)[1:count+1]

print(final_images.shape, final_masks.shape)
# Out:
# (100, 512, 512, 3) (100, 512, 512, 1)

# %%
from sklearn.model_selection import train_test_split

training_images, validation_images, training_labels, validation_labels = train_test_split(
    final_images,final_masks, test_size=0.4, random_state=42)

# %%
training_data_size = len(training_images) 
training_labels_size = len(training_labels) 
testing_data_size = len(validation_images) 
testing_labels_size = len(validation_labels)  

train_sizes = [training_data_size, training_labels_size]
test_sizes = [testing_data_size, testing_labels_size]
train_labels = ['Training Images', 'Training Masks']
test_labels = ['Testing Images', 'Testing Masks']

def absolute_value(val, total):
    return int(round(val/100.*total))

fig, axs = plt.subplots(1, 2, figsize=(14, 7))

axs[0].pie(train_sizes, labels=train_labels, autopct=lambda val: absolute_value(val, sum(train_sizes)), startangle=140, colors=['blue', 'green'])
axs[0].set_title('Training Data Distribution')

axs[1].pie(test_sizes, labels=test_labels, autopct=lambda val: absolute_value(val, sum(test_sizes)), startangle=140, colors=['red', 'purple'])
axs[1].set_title('Testing Data Distribution')

plt.tight_layout()
plt.show()

# %%
import tensorflow as tf

def convolutional_block(input, filters):
    x = tf.keras.layers.Conv2D(filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x

def encoding_block(input, filters):
    skip_connection = convolutional_block(input, filters)
    pooled = tf.keras.layers.MaxPool2D((2, 2))(skip_connection)
    return skip_connection, pooled

def decoding_block(input, skip_connection, filters):
    x = tf.keras.layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(input)
    x = tf.keras.layers.Concatenate()([x, skip_connection])
    x = convolutional_block(x, filters)
    return x

def build_unet_model(input_shape, base_filters=32):  # Уменьшенное начальное количество фильтров
    inputs = tf.keras.layers.Input(input_shape)

    skip_connection1, pool1 = encoding_block(inputs, 32)
    skip_connection2, pool2 = encoding_block(pool1, 64)
    skip_connection3, pool3 = encoding_block(pool2, 128)
    skip_connection4, pool4 = encoding_block(pool3, 256)
    bridge = convolutional_block(pool4, 512)

    decode_block1 = decoding_block(bridge, skip_connection4, 256)
    decode_block2 = decoding_block(decode_block1, skip_connection3, 128)
    decode_block3 = decoding_block(decode_block2, skip_connection2, 64)
    decode_block4 = decoding_block(decode_block3, skip_connection1, 32)

    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(decode_block4)
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="Refactored-U-Net")
    return model

# Создание упрощенной модели с базовыми фильтрами 32
refactored_unet_model = build_unet_model((512, 512, 3), base_filters=32)
refactored_unet_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 2024-04-04 19:45:48.396835: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 19:45:48.396935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 19:45:48.526852: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
training_history = refactored_unet_model.fit(training_images, training_labels,validation_split=0.2, batch_size=4,epochs=130)
# Out:
# Epoch 1/130
# 2024-04-04 19:46:12.942825: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.28217, expected 2.80856
# 2024-04-04 19:46:12.942888: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 20: 3.65984, expected 3.18622
# 2024-04-04 19:46:12.942907: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 146: 3.18374, expected 2.71012
# 2024-04-04 19:46:12.942924: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 289: 3.72308, expected 3.24946
# 2024-04-04 19:46:12.942937: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 467: 3.36379, expected 2.89017
# 2024-04-04 19:46:12.943003: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6144: 3.64194, expected 3.16832
# 2024-04-04 19:46:12.943423: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 56320: 3.51982, expected 3.0462
# 2024-04-04 19:46:12.943595: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 73216: 3.25333, expected 2.77971
# 2024-04-04 19:46:12.943905: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 117760: 3.66772, expected 3.1941
# 2024-04-04 19:46:12.944028: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 128512: 3.44279, expected 2.96917
# 2024-04-04 19:46:12.958849: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 19:46:12.958884: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 19:46:12.958899: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 19:46:12.958913: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 19:46:12.958927: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 19:46:12.958946: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 19:46:13.376662: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.28217, expected 2.80856
# 2024-04-04 19:46:13.376718: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 20: 3.65984, expected 3.18622
# 2024-04-04 19:46:13.376735: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 146: 3.18374, expected 2.71012
# 2024-04-04 19:46:13.376753: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 289: 3.72308, expected 3.24946
# 2024-04-04 19:46:13.376768: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 467: 3.36379, expected 2.89017
# 2024-04-04 19:46:13.376815: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6144: 3.64194, expected 3.16832
# 2024-04-04 19:46:13.377212: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 56320: 3.51982, expected 3.0462
# 2024-04-04 19:46:13.377365: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 73216: 3.25333, expected 2.77971
# 2024-04-04 19:46:13.377663: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 117760: 3.66772, expected 3.1941
# 2024-04-04 19:46:13.377783: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 128512: 3.44279, expected 2.96917
# 2024-04-04 19:46:13.393002: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 19:46:13.393032: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 19:46:13.393045: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 19:46:13.393055: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 19:46:13.393071: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 19:46:13.393091: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 7:36 41s/step - accuracy: 0.5202 - loss: 0.5485
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712260000.578674      90 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 45s 315ms/step - accuracy: 0.5950 - loss: -0.9691 - val_accuracy: 3.2107e-05 - val_loss: -3080.4988
# Epoch 2/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8175 - loss: -5.9596 - val_accuracy: 0.0000e+00 - val_loss: -15406.5771
# Epoch 3/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8321 - loss: -8.3109 - val_accuracy: 0.0083 - val_loss: -11187.5205
# Epoch 4/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8460 - loss: -9.4220 - val_accuracy: 0.0074 - val_loss: -2593.9358
# Epoch 5/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8256 - loss: -14.2144 - val_accuracy: 0.0032 - val_loss: -1920.6283
# Epoch 6/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7094 - loss: -12.9494 - val_accuracy: 0.0236 - val_loss: -1855.6865
# Epoch 7/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7977 - loss: -19.1244 - val_accuracy: 0.9815 - val_loss: 3.2990
# Epoch 8/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7356 - loss: -23.9234 - val_accuracy: 0.9877 - val_loss: 5.1946
# Epoch 9/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6457 - loss: -28.7070 - val_accuracy: 0.2736 - val_loss: -3.1590
# Epoch 10/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6080 - loss: -40.3379 - val_accuracy: 0.5663 - val_loss: -0.5270
# Epoch 11/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6279 - loss: -48.9881 - val_accuracy: 0.9918 - val_loss: 8.3217
# Epoch 12/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.5744 - loss: -50.9000 - val_accuracy: 0.7494 - val_loss: -56.1631
# Epoch 13/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.5769 - loss: -59.2108 - val_accuracy: 0.4971 - val_loss: -66.9132
# Epoch 14/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6286 - loss: -66.0788 - val_accuracy: 0.4049 - val_loss: -97.0855
# Epoch 15/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6477 - loss: -79.2937 - val_accuracy: 0.3133 - val_loss: -356.0691
# Epoch 16/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6396 - loss: -83.3588 - val_accuracy: 0.2927 - val_loss: -17.8203
# Epoch 17/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6536 - loss: -92.2495 - val_accuracy: 0.4845 - val_loss: -270.7645
# Epoch 18/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6383 - loss: -99.9358 - val_accuracy: 0.1687 - val_loss: -147.4268
# Epoch 19/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6932 - loss: -111.5037 - val_accuracy: 0.0731 - val_loss: -133.6185
# Epoch 20/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.5649 - loss: -116.2482 - val_accuracy: 0.1529 - val_loss: -53.4294
# Epoch 21/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6589 - loss: -124.7763 - val_accuracy: 0.1893 - val_loss: -12.1575
# Epoch 22/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7058 - loss: -120.9195 - val_accuracy: 0.6472 - val_loss: -10.2446
# Epoch 23/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6275 - loss: -144.2589 - val_accuracy: 0.7252 - val_loss: -2.8773
# Epoch 24/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6940 - loss: -156.6669 - val_accuracy: 0.6867 - val_loss: -2.3228
# Epoch 25/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6919 - loss: -173.8323 - val_accuracy: 0.4167 - val_loss: -8.5689
# Epoch 26/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6691 - loss: -172.9580 - val_accuracy: 0.3800 - val_loss: -19.3241
# Epoch 27/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7163 - loss: -190.0816 - val_accuracy: 0.2000 - val_loss: -16.8258
# Epoch 28/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6905 - loss: -197.8799 - val_accuracy: 0.4350 - val_loss: -13.1744
# Epoch 29/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7013 - loss: -226.0175 - val_accuracy: 0.3464 - val_loss: -9.6736
# Epoch 30/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6817 - loss: -214.3334 - val_accuracy: 0.3450 - val_loss: -15.2702
# Epoch 31/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6752 - loss: -228.6101 - val_accuracy: 0.6071 - val_loss: -0.1934
# Epoch 32/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7166 - loss: -222.4385 - val_accuracy: 0.4512 - val_loss: -68.8922
# Epoch 33/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7330 - loss: -260.2810 - val_accuracy: 0.3851 - val_loss: -42.4875
# Epoch 34/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7298 - loss: -254.3620 - val_accuracy: 0.3230 - val_loss: -10.0792
# Epoch 35/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7512 - loss: -251.8999 - val_accuracy: 0.5166 - val_loss: -37.6813
# Epoch 36/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7373 - loss: -277.2219 - val_accuracy: 0.4985 - val_loss: -27.0676
# Epoch 37/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7141 - loss: -280.5150 - val_accuracy: 0.4862 - val_loss: -83.7701
# Epoch 38/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7234 - loss: -302.5203 - val_accuracy: 0.4536 - val_loss: -20.8565
# Epoch 39/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7098 - loss: -308.2481 - val_accuracy: 0.5873 - val_loss: -58.2148
# Epoch 40/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7523 - loss: -335.2487 - val_accuracy: 0.6130 - val_loss: -9.5419
# Epoch 41/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7391 - loss: -318.9205 - val_accuracy: 0.2446 - val_loss: -88.6807
# Epoch 42/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7259 - loss: -332.2462 - val_accuracy: 0.8350 - val_loss: -47.8409
# Epoch 43/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7648 - loss: -364.6781 - val_accuracy: 0.8186 - val_loss: -25.2714
# Epoch 44/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7620 - loss: -358.9973 - val_accuracy: 0.9333 - val_loss: -30.8297
# Epoch 45/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7563 - loss: -372.3355 - val_accuracy: 0.6121 - val_loss: -7.8222
# Epoch 46/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7721 - loss: -403.3358 - val_accuracy: 0.4283 - val_loss: -2.7004
# Epoch 47/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7443 - loss: -407.2358 - val_accuracy: 0.6554 - val_loss: -111.8655
# Epoch 48/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7584 - loss: -411.2728 - val_accuracy: 0.6478 - val_loss: -308.8181
# Epoch 49/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7659 - loss: -425.6740 - val_accuracy: 0.5876 - val_loss: -120.1573
# Epoch 50/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7923 - loss: -467.5520 - val_accuracy: 0.8517 - val_loss: -55.0583
# Epoch 51/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7978 - loss: -456.4950 - val_accuracy: 0.5447 - val_loss: -41.8983
# Epoch 52/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7667 - loss: -444.4454 - val_accuracy: 0.4935 - val_loss: -117.9454
# Epoch 53/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7672 - loss: -494.9554 - val_accuracy: 0.6955 - val_loss: -187.8621
# Epoch 54/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7759 - loss: -485.7455 - val_accuracy: 0.2720 - val_loss: -10.6322
# Epoch 55/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7305 - loss: -463.4925 - val_accuracy: 0.3949 - val_loss: -164.9716
# Epoch 56/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7429 - loss: -517.3091 - val_accuracy: 0.5627 - val_loss: -251.5350
# Epoch 57/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7520 - loss: -519.2151 - val_accuracy: 0.9100 - val_loss: -136.0416
# Epoch 58/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7352 - loss: -523.2899 - val_accuracy: 0.8667 - val_loss: -36.9353
# Epoch 59/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7682 - loss: -532.1042 - val_accuracy: 0.1659 - val_loss: -437.7926
# Epoch 60/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8002 - loss: -575.3849 - val_accuracy: 0.6472 - val_loss: -130.6645
# Epoch 61/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7922 - loss: -627.8528 - val_accuracy: 0.7892 - val_loss: -194.2963
# Epoch 62/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8175 - loss: -586.4254 - val_accuracy: 0.6197 - val_loss: -359.8673
# Epoch 63/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8131 - loss: -595.9125 - val_accuracy: 0.7197 - val_loss: -163.5696
# Epoch 64/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8018 - loss: -656.1629 - val_accuracy: 0.5137 - val_loss: -337.0269
# Epoch 65/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8114 - loss: -655.9854 - val_accuracy: 0.6078 - val_loss: -95.8773
# Epoch 66/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7731 - loss: -662.5374 - val_accuracy: 0.7321 - val_loss: -171.2942
# Epoch 67/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7462 - loss: -705.9230 - val_accuracy: 0.8318 - val_loss: -331.1264
# Epoch 68/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7702 - loss: -717.9565 - val_accuracy: 0.7449 - val_loss: -17.2610
# Epoch 69/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7686 - loss: -698.4470 - val_accuracy: 0.8433 - val_loss: -107.4736
# Epoch 70/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8089 - loss: -725.4082 - val_accuracy: 0.8734 - val_loss: -151.8885
# Epoch 71/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8116 - loss: -757.8540 - val_accuracy: 0.9298 - val_loss: -53.3453
# Epoch 72/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7963 - loss: -778.1428 - val_accuracy: 0.8779 - val_loss: -25.8554
# Epoch 73/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7853 - loss: -822.8513 - val_accuracy: 0.7739 - val_loss: -86.4263
# Epoch 74/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7927 - loss: -823.3257 - val_accuracy: 0.7604 - val_loss: -16.4692
# Epoch 75/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8065 - loss: -812.8564 - val_accuracy: 0.8429 - val_loss: -92.6662
# Epoch 76/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7909 - loss: -826.6837 - val_accuracy: 0.9480 - val_loss: -37.7015
# Epoch 77/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8046 - loss: -869.5402 - val_accuracy: 0.9347 - val_loss: -36.1290
# Epoch 78/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7867 - loss: -840.9059 - val_accuracy: 0.3196 - val_loss: -14.4163
# Epoch 79/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7701 - loss: -851.6095 - val_accuracy: 0.8990 - val_loss: -137.8457
# Epoch 80/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.7926 - loss: -880.5712 - val_accuracy: 0.5133 - val_loss: -295.7550
# Epoch 81/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7841 - loss: -887.3532 - val_accuracy: 0.5713 - val_loss: -57.9111
# Epoch 82/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8399 - loss: -926.0981 - val_accuracy: 0.7261 - val_loss: -66.8641
# Epoch 83/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8101 - loss: -997.1011 - val_accuracy: 0.8252 - val_loss: -26.3063
# Epoch 84/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8024 - loss: -1030.9047 - val_accuracy: 0.8328 - val_loss: -95.9192
# Epoch 85/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8040 - loss: -1019.4680 - val_accuracy: 0.7347 - val_loss: -163.8228
# Epoch 86/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7600 - loss: -970.7903 - val_accuracy: 0.7716 - val_loss: -62.6739
# Epoch 87/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8152 - loss: -1038.5371 - val_accuracy: 0.8426 - val_loss: -277.7415
# Epoch 88/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7542 - loss: -1042.9142 - val_accuracy: 0.7173 - val_loss: -176.3050
# Epoch 89/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7909 - loss: -1076.4803 - val_accuracy: 0.9072 - val_loss: -58.6737
# Epoch 90/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8289 - loss: -1120.7950 - val_accuracy: 0.8670 - val_loss: -18.5915
# Epoch 91/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8158 - loss: -1135.5431 - val_accuracy: 0.9204 - val_loss: -117.5231
# Epoch 92/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.8168 - loss: -1113.4419 - val_accuracy: 0.6825 - val_loss: -51.1432
# Epoch 93/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7842 - loss: -1173.8346 - val_accuracy: 0.9158 - val_loss: -165.0036
# Epoch 94/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8255 - loss: -1214.2775 - val_accuracy: 0.9133 - val_loss: -31.3577
# Epoch 95/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7916 - loss: -1145.2976 - val_accuracy: 0.8260 - val_loss: -85.6870
# Epoch 96/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7647 - loss: -1150.3739 - val_accuracy: 0.9350 - val_loss: -123.8984
# Epoch 97/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8099 - loss: -1277.8053 - val_accuracy: 0.9029 - val_loss: -49.5058
# Epoch 98/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8343 - loss: -1285.5990 - val_accuracy: 0.9038 - val_loss: -302.3579
# Epoch 99/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8157 - loss: -1306.1343 - val_accuracy: 0.9409 - val_loss: -220.6915
# Epoch 100/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7764 - loss: -1246.1859 - val_accuracy: 0.9829 - val_loss: -197.5419
# Epoch 101/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8096 - loss: -1327.7767 - val_accuracy: 0.9481 - val_loss: -182.5934
# Epoch 102/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7827 - loss: -1260.9332 - val_accuracy: 0.9615 - val_loss: -82.8977
# Epoch 103/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7941 - loss: -1343.8478 - val_accuracy: 0.9127 - val_loss: -172.9009
# Epoch 104/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8257 - loss: -1430.1038 - val_accuracy: 0.9792 - val_loss: -243.6920
# Epoch 105/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7953 - loss: -1384.3444 - val_accuracy: 0.9835 - val_loss: -93.6472
# Epoch 106/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8554 - loss: -1494.9231 - val_accuracy: 0.9875 - val_loss: -89.8627
# Epoch 107/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7938 - loss: -1394.1893 - val_accuracy: 0.9818 - val_loss: -45.2340
# Epoch 108/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7974 - loss: -1386.7278 - val_accuracy: 0.9833 - val_loss: -190.6249
# Epoch 109/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7994 - loss: -1492.0302 - val_accuracy: 0.9811 - val_loss: -153.2285
# Epoch 110/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7974 - loss: -1454.6676 - val_accuracy: 0.9032 - val_loss: -297.5895
# Epoch 111/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8414 - loss: -1589.0776 - val_accuracy: 0.9799 - val_loss: -224.0154
# Epoch 112/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8374 - loss: -1642.0703 - val_accuracy: 0.9822 - val_loss: -200.6706
# Epoch 113/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.7682 - loss: -1478.7627 - val_accuracy: 0.9843 - val_loss: -127.4635
# Epoch 114/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8177 - loss: -1554.1212 - val_accuracy: 0.9845 - val_loss: -252.9326
# Epoch 115/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8137 - loss: -1614.7515 - val_accuracy: 0.9812 - val_loss: -190.9368
# Epoch 116/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8076 - loss: -1636.7046 - val_accuracy: 0.9719 - val_loss: -161.8536
# Epoch 117/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7994 - loss: -1698.8031 - val_accuracy: 0.9471 - val_loss: -216.1968
# Epoch 118/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8423 - loss: -1713.1960 - val_accuracy: 0.9763 - val_loss: -328.0248
# Epoch 119/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7932 - loss: -1669.4954 - val_accuracy: 0.9213 - val_loss: -262.3441
# Epoch 120/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8102 - loss: -1757.6697 - val_accuracy: 0.9453 - val_loss: -168.2113
# Epoch 121/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7988 - loss: -1782.1083 - val_accuracy: 0.9685 - val_loss: -210.2055
# Epoch 122/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8398 - loss: -1842.0457 - val_accuracy: 0.9548 - val_loss: -172.8192
# Epoch 123/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.7655 - loss: -1693.3665 - val_accuracy: 0.9885 - val_loss: -33.1058
# Epoch 124/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8424 - loss: -1804.3247 - val_accuracy: 0.9715 - val_loss: -828.1834
# Epoch 125/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8078 - loss: -1944.0067 - val_accuracy: 0.9721 - val_loss: -395.0504
# Epoch 126/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8024 - loss: -1911.9298 - val_accuracy: 0.9777 - val_loss: -450.2466
# Epoch 127/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8114 - loss: -1940.0746 - val_accuracy: 0.9677 - val_loss: -219.0780
# Epoch 128/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8225 - loss: -1942.9963 - val_accuracy: 0.8983 - val_loss: -249.8275
# Epoch 129/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8162 - loss: -1882.3413 - val_accuracy: 0.9809 - val_loss: -304.6093
# Epoch 130/130
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8241 - loss: -1977.2548 - val_accuracy: 0.9750 - val_loss: -294.8475

# %%
def display_segmentation(idx, original_img, predicted_mask, true_mask, threshold):
    figure, axes = plt.subplots(1, 3, figsize=(12, 4))

    axes[0].set_title(f"Original Image #{idx}")
    axes[0].imshow(original_img)
    axes[0].axis('off')

    axes[1].set_title(f"U-Net Prediction (Threshold: {threshold})")
    axes[1].imshow(predicted_mask, cmap='gray')
    axes[1].axis('off')

    axes[2].set_title("Ground Truth Mask")
    axes[2].imshow(true_mask, cmap='gray')
    axes[2].axis('off')

    plt.show()

# %%
predictions = refactored_unet_model.predict(validation_images)
# Out:
# 2024-04-04 19:50:52.119035: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-04-04 19:50:53.012651: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.21244, expected 2.29141
# 2024-04-04 19:50:53.012705: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.49015, expected 3.56912
# 2024-04-04 19:50:53.012715: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 3.96535, expected 3.04432
# 2024-04-04 19:50:53.012723: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 4.09082, expected 3.16979
# 2024-04-04 19:50:53.012732: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 3.442, expected 2.52097
# 2024-04-04 19:50:53.012740: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.32599, expected 3.40496
# 2024-04-04 19:50:53.012748: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.35973, expected 3.4387
# 2024-04-04 19:50:53.012755: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.41635, expected 3.49532
# 2024-04-04 19:50:53.012763: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.19727, expected 3.27624
# 2024-04-04 19:50:53.012771: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.76075, expected 3.83972
# 2024-04-04 19:50:53.130215: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 19:50:53.130272: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 19:50:53.130282: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 19:50:53.130289: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 19:50:53.130296: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 19:50:53.130313: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 19:50:53.130356: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.011465463s
# Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-04-04 19:50:54.975811: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-04-04 19:50:55.867831: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.21244, expected 2.29141
# 2024-04-04 19:50:55.867892: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.49015, expected 3.56912
# 2024-04-04 19:50:55.867907: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 3.96535, expected 3.04432
# 2024-04-04 19:50:55.867923: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 4.09082, expected 3.16979
# 2024-04-04 19:50:55.867938: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 3.442, expected 2.52097
# 2024-04-04 19:50:55.867948: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.32599, expected 3.40496
# 2024-04-04 19:50:55.867960: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.35973, expected 3.4387
# 2024-04-04 19:50:55.867986: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.41635, expected 3.49532
# 2024-04-04 19:50:55.867996: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.19727, expected 3.27624
# 2024-04-04 19:50:55.868006: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.76075, expected 3.83972
# 2024-04-04 19:50:55.985516: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 19:50:55.985577: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 19:50:55.985590: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 19:50:55.985602: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 19:50:55.985617: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 19:50:55.985641: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 19:50:55.985696: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.010022052s
# Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 54s 55s/step
# 2024-04-04 19:51:46.057269: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.56918, expected 2.8525
# 2024-04-04 19:51:46.057321: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 5.56898, expected 4.85231
# 2024-04-04 19:51:46.057330: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.7052, expected 3.98853
# 2024-04-04 19:51:46.057338: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.01271, expected 4.29603
# 2024-04-04 19:51:46.057346: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.54539, expected 3.82871
# 2024-04-04 19:51:46.057354: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.41696, expected 4.70029
# 2024-04-04 19:51:46.057361: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.06138, expected 4.34471
# 2024-04-04 19:51:46.057369: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.3757, expected 3.65902
# 2024-04-04 19:51:46.057377: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.12874, expected 4.41207
# 2024-04-04 19:51:46.057384: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.79334, expected 4.07667
# 2024-04-04 19:51:46.087647: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 19:51:46.087679: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 19:51:46.087688: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 19:51:46.087695: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 19:51:46.087702: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 19:51:46.087717: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 19:51:46.783165: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.56918, expected 2.8525
# 2024-04-04 19:51:46.783217: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 5.56898, expected 4.85231
# 2024-04-04 19:51:46.783226: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.7052, expected 3.98853
# 2024-04-04 19:51:46.783234: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.01271, expected 4.29603
# 2024-04-04 19:51:46.783242: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.54539, expected 3.82871
# 2024-04-04 19:51:46.783250: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.41696, expected 4.70029
# 2024-04-04 19:51:46.783258: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.06138, expected 4.34471
# 2024-04-04 19:51:46.783266: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.3757, expected 3.65902
# 2024-04-04 19:51:46.783273: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.12874, expected 4.41207
# 2024-04-04 19:51:46.783281: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.79334, expected 4.07667
# 2024-04-04 19:51:46.813018: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,32,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,3,512,512]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 19:51:46.813063: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 19:51:46.813074: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 19:51:46.813081: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 19:51:46.813088: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 19:51:46.813104: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 70s 16s/step

# %%
thresholds = [0.7, 0.8, 0.9]

segmentation_masks = [(predictions > threshold).astype(np.uint8) for threshold in thresholds]
sample_indices = random.sample(range(len(predictions)), 5)

for index in sample_indices:
    for mask, threshold in zip(segmentation_masks, thresholds):
        display_segmentation(index, validation_images[index], mask[index], validation_labels[index], threshold)
    print()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# Предположим, что ваши предсказания и истинные метки имеют форму (количество примеров, высота, ширина)
# Например, для задачи сегментации изображений
binary_predictions = (predictions > 0.5).astype(np.uint8)  # Бинаризация
y_true = validation_labels.flatten()  # Выравнивание истинных меток
y_pred = binary_predictions.flatten()  # Выравнивание предсказаний

# Расчет матрицы ошибок
conf_matrix = confusion_matrix(y_true, y_pred)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(conf_matrix, annot=True, fmt="d")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
